# %%
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
url1 = "https://archive.ics.uci.edu/ml/machine-learning-databases/image/segmentation.data"
url2 = "https://archive.ics.uci.edu/ml/machine-learning-databases/image/segmentation.test"

cols = ["CLASS", "REGION-CENTROID-COL", "REGION-CENTROID-ROW", "REGION-PIXEL-COUNT", "SHORT-LINE-DENSITY-5", "SHORT-LINE-DENSITY-2", "VEDGE-MEAN", "VEDGE-SD", "HEDGE-MEAN", "HEDGE-SD", "INTENSITY-MEAN","RAWRED-MEAN","RAWBLUE-MEAN","RAWGREEN-MEAN","EXRED-MEAN","EXBLUE-MEAN","EXGREEN-MEAN","VALUE-MEAN","SATURATION-MEAN","HUE-MEAN"]

data1 = pd.read_csv(url1, header=2, names=cols)
data2 = pd.read_csv(url2, header=2, names=cols)
data = pd.concat([data1, data2]).drop(["REGION-CENTROID-COL", "REGION-CENTROID-ROW", "REGION-PIXEL-COUNT"], axis=1)
data
# Out:
#           CLASS  SHORT-LINE-DENSITY-5  SHORT-LINE-DENSITY-2  VEDGE-MEAN  \
# 0     BRICKFACE              0.000000                   0.0    0.277778
# 1     BRICKFACE              0.000000                   0.0    0.333333
# 2     BRICKFACE              0.000000                   0.0    0.277778
# 3     BRICKFACE              0.000000                   0.0    0.500000
# 4     BRICKFACE              0.000000                   0.0    0.722222
# ...         ...                   ...                   ...         ...
# 2095     CEMENT              0.000000                   0.0    0.944445
# 2096     CEMENT              0.111111                   0.0    1.611111
# 2097     CEMENT              0.000000                   0.0    0.555555
# 2098     CEMENT              0.000000                   0.0    2.166667
# 2099     CEMENT              0.111111                   0.0    1.388889
#
#       VEDGE-SD  HEDGE-MEAN  HEDGE-SD  INTENSITY-MEAN  RAWRED-MEAN  \
# 0     0.062963    0.666667  0.311111        6.185185     7.333334
# 1     0.266667    0.500000  0.077778        6.666666     8.333334
# 2     0.107407    0.833333  0.522222        6.111111     7.555555
# 3     0.166667    1.111111  0.474074        5.851852     7.777778
# 4     0.374074    0.888889  0.429629        6.037037     7.000000
# ...        ...         ...       ...             ...          ...
# 2095  0.862963    0.833333  0.611111        7.962963     6.333334
# 2096  2.062962    0.333333  0.133333        8.370370     6.666666
# 2097  0.251852    0.777778  0.162963        7.148148     5.555555
# 2098  1.633334    1.388889  0.418518        8.444445     7.000000
# 2099  1.129630    2.000000  0.888889       10.037037     8.000000
#
#       RAWBLUE-MEAN  RAWGREEN-MEAN  EXRED-MEAN  EXBLUE-MEAN  EXGREEN-MEAN  \
# 0         7.666666       3.555556    3.444444     4.444445     -7.888889
# 1         7.777778       3.888889    5.000000     3.333333     -8.333333
# 2         7.222222       3.555556    4.333334     3.333333     -7.666666
# 3         6.444445       3.333333    5.777778     1.777778     -7.555555
# 4         7.666666       3.444444    2.888889     4.888889     -7.777778
# ...            ...            ...         ...          ...           ...
# 2095     11.888889       5.666666   -4.888889    11.777778     -6.888889
# 2096     12.000000       6.444445   -5.111111    10.888889     -5.777778
# 2097     10.888889       5.000000   -4.777778    11.222222     -6.444445
# 2098     12.222222       6.111111   -4.333334    11.333333     -7.000000
# 2099     14.555555       7.555555   -6.111111    13.555555     -7.444445
#
#       VALUE-MEAN  SATURATION-MEAN  HUE-MEAN
# 0       7.777778         0.545635 -1.121818
# 1       8.444445         0.538580 -0.924817
# 2       7.555555         0.532628 -0.965946
# 3       7.777778         0.573633 -0.744272
# 4       7.888889         0.562919 -1.175773
# ...          ...              ...       ...
# 2095   11.888889         0.520578 -1.982834
# 2096   12.000000         0.484805 -2.044946
# 2097   10.888889         0.540918 -1.996307
# 2098   12.222222         0.503086 -1.943449
# 2099   14.555555         0.479931 -2.029312
#
# [2310 rows x 17 columns]

# %%
sns.countplot(data, x="CLASS")
# Out:
# <AxesSubplot:xlabel='CLASS', ylabel='count'>

# %%
for feature in data:
    print(data[feature].describe(), "\n")
# Out:
# count          2310
# unique            7
# top       BRICKFACE
# freq            330
# Name: CLASS, dtype: object
#
# count    2310.000000
# mean        0.014334
# std         0.040154
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         0.333333
# Name: SHORT-LINE-DENSITY-5, dtype: float64
#
# count    2310.000000
# mean        0.004714
# std         0.024234
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         0.222222
# Name: SHORT-LINE-DENSITY-2, dtype: float64
#
# count    2310.000000
# mean        1.893939
# std         2.698908
# min         0.000000
# 25%         0.722222
# 50%         1.222224
# 75%         2.166667
# max        29.222221
# Name: VEDGE-MEAN, dtype: float64
#
# count    2310.000000
# mean        5.709320
# std        44.846457
# min         0.000000
# 25%         0.355555
# 50%         0.833333
# 75%         1.806367
# max       991.718400
# Name: VEDGE-SD, dtype: float64
#
# count    2310.000000
# mean        2.424723
# std         3.610084
# min         0.000000
# 25%         0.777780
# 50%         1.444444
# 75%         2.555556
# max        44.722225
# Name: HEDGE-MEAN, dtype: float64
#
# count    2.310000e+03
# mean     8.243692e+00
# std      5.881152e+01
# min     -1.589457e-08
# 25%      4.216373e-01
# 50%      9.629633e-01
# 75%      2.183269e+00
# max      1.386329e+03
# Name: HEDGE-SD, dtype: float64
#
# count    2310.000000
# mean       37.051595
# std        38.176410
# min         0.000000
# 25%         7.296296
# 50%        21.592592
# 75%        53.212964
# max       143.444440
# Name: INTENSITY-MEAN, dtype: float64
#
# count    2310.000000
# mean       32.821308
# std        35.036774
# min         0.000000
# 25%         7.000000
# 50%        19.555555
# 75%        47.333332
# max       137.111110
# Name: RAWRED-MEAN, dtype: float64
#
# count    2310.000000
# mean       44.187879
# std        43.527461
# min         0.000000
# 25%         9.555555
# 50%        27.666667
# 75%        64.888890
# max       150.888890
# Name: RAWBLUE-MEAN, dtype: float64
#
# count    2310.000000
# mean       34.145599
# std        36.364773
# min         0.000000
# 25%         6.027778
# 50%        20.333334
# 75%        46.500001
# max       142.555560
# Name: RAWGREEN-MEAN, dtype: float64
#
# count    2310.000000
# mean      -12.690861
# std        11.583562
# min       -49.666668
# 25%       -18.555555
# 50%       -10.888889
# 75%        -4.222222
# max         9.888889
# Name: EXRED-MEAN, dtype: float64
#
# count    2310.000000
# mean       21.408850
# std        19.571819
# min       -12.444445
# 25%         4.138889
# 50%        19.666666
# 75%        35.777780
# max        82.000000
# Name: EXBLUE-MEAN, dtype: float64
#
# count    2310.000000
# mean       -8.717989
# std        11.551628
# min       -33.888890
# 25%       -16.777779
# 50%       -10.888889
# 75%        -3.222222
# max        24.666666
# Name: EXGREEN-MEAN, dtype: float64
#
# count    2310.000000
# mean       45.137470
# std        42.921764
# min         0.000000
# 25%        11.555555
# 50%        28.666666
# 75%        64.888890
# max       150.888890
# Name: VALUE-MEAN, dtype: float64
#
# count    2310.000000
# mean        0.426893
# std         0.228309
# min         0.000000
# 25%         0.284235
# 50%         0.374803
# 75%         0.540123
# max         1.000000
# Name: SATURATION-MEAN, dtype: float64
#
# count    2310.000000
# mean       -1.362897
# std         1.545335
# min        -3.044175
# 25%        -2.188057
# 50%        -2.051200
# 75%        -1.562308
# max         2.912480
# Name: HUE-MEAN, dtype: float64

# %%
for feature in data.drop(["CLASS"], axis=1):
    sns.displot(data, x=data[feature], kind="hist")

# %%
for feature in data.drop(["CLASS"], axis=1):
    sns.displot(data, x=data[feature], kind="kde", hue=data["CLASS"], palette="pastel")

# %%
warnings.filterwarnings('ignore')

for feature in data.drop(["CLASS"], axis=1):
    for c in data["CLASS"].unique():
        sns.distplot(data[feature][data["CLASS"]==c],
                 kde=1,label='{}'.format(c))

    plt.legend()
    plt.show()
